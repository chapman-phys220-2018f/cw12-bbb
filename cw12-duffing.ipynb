# %%
import numpy as np
import sombrero as som

# %%
x0 = -0.9
y0 = 0
F = 0.18
N = 500

# %%
som.RK4(-0.9, 0, 0.18, 500)

# %% [markdown]
# The ball rolls between one well, moving up along the wall of the well and back down to the opposite wall like a pendulum. If we graph the velocity v. position, we would have a circular graph showing the motion of the ball.

# %%
x0 = 0.9
y0 = 0
F = 0.18
N = 500

# %%
som.RK4(0.9, 0, 0.18, 500)

# %% [markdown]
# The ball now starts in the positive well and continus to roll in this well during the entire duration.

# %%
x0 = 0.2
y0 = 0.1
F = 0.25
N = 500

# %%
som.RK4(0.2, 0.1, 0.25, 500)

# %% [markdown]
# By increasing y0 and starting the ball at a higher point and increasing the force, we allow it to build enough speed to cross between the barrier between the wells. We can see that the speed of the ball decreases where the barrier is because it needs to get over this hump. It also looks like during the second half of the ball rolling it did not have enough velocity to get out of the positive well and remained here for the rest of the time.

# %%
x0 = 0.201
y0 = 0.1
F = 0.25
N = 500

# %%
som.RK4(0.201, 0.1, 0.25, 500)

# %% [markdown]
# We increased the x0 by 0.001. This changed the motion of the ball enough to where it now ends in the negative well.

# %%
x0 = 0
y0 = 0
F = 0.4
N = 500

# %%
som.RK4(0, 0, 0.4, 500)

# %% [markdown]
# Force was increased to 0.4 with the ball beginning on the barrier at rest. This showed a much more chaotic motion with the ball continuously crossing between the two wells.

# %%
x0 = 0
y0 = 0
F = 0.4
N = 500

# %%
som.RK4_2(0, 0, 0.4, 500)

# %% [markdown]
# The ball is allowed to settle into the well before force is applied, sending it to the other well.
